# %% [markdown]
# # Preprocessing: SMILES → Descriptor Features for Melting Point
#
#
# This notebook computes descriptor features from SMILES for modeling melting point (`Tm`).
#
#
# Descriptors include: α (H-bond donor ability), π (hydrophobic constant via logP), MR (Molar Refractivity), B2 (Sterimol width), and I3 (meta-substitution indicator).

# %%
import json
import subprocess
import sys

def ensure_package(import_name: str, install_name: str | None = None) -> None:
    """Install a pip package if missing (best-effort)."""
    install_name = install_name or import_name
    result = subprocess.run(
        [sys.executable, '-m', 'pip', 'list', '--format=json'],
        check=True,
        capture_output=True,
        text=True,
    )
    installed = {pkg['name'].lower() for pkg in json.loads(result.stdout)}
    # Some packages have different import vs distribution names (e.g., rdkit-pypi -> rdkit)
    if import_name.lower() in installed or (install_name and install_name.lower() in installed):
        print(f'{import_name} already installed.')
        return
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', install_name])
    print(f'Installed {install_name} (import as {import_name}).')

# Install baseline modeling deps if missing (best-effort)
for pkg in [
    ('scikit-learn', 'scikit-learn'),
    ('lightgbm', 'lightgbm'),
    ('numpy', 'numpy'),
    ('pandas', 'pandas'),
    ('rdkit', 'rdkit'),
]:
    try:
        ensure_package(pkg[0], pkg[1])
    except Exception as exc:
        print(f"Package install check failed for {pkg}: {exc}")
# Out:
# scikit-learn already installed.
# lightgbm already installed.
# numpy already installed.
# pandas already installed.
# rdkit already installed.

# %%
# Descriptor computation helpers


from typing import Dict, Optional


import numpy as np

import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Crippen
from rdkit.Chem import rdMolDescriptors

def _embed_3d(mol: Chem.Mol, seed: int = 13) -> Chem.Mol:


    mol = Chem.AddHs(mol)


    params = AllChem.ETKDGv3()


    params.randomSeed = seed


    _ = AllChem.EmbedMolecule(mol, params)


    try:


        AllChem.UFFOptimizeMolecule(mol, maxIters=200)


    except Exception:


        pass


    return mol




def compute_b2(mol: Chem.Mol) -> Optional[float]:


    """Compute Sterimol B2 if available via mordred; else fallback to PCA width (approx)."""


    # Try mordred Sterimol.B2 if present


    try:


        SterimolMod = getattr(descriptors, "Sterimol")


        B2class = getattr(SterimolMod, "B2")


        calc = Calculator(B2class())


        val = calc(mol)[0]


        if val is not None:


            return float(val)


    except Exception as e:


        # Will try approximate method below


        pass




    # RDKit-based approximate B2: width along 2nd principal axis


    try:


        m3d = Chem.Mol(mol)


        if m3d.GetNumConformers() == 0:


            m3d = _embed_3d(Chem.Mol(mol))


        conf = m3d.GetConformer()


        coords = []


        for a in m3d.GetAtoms():


            pos = conf.GetAtomPosition(a.GetIdx())


            coords.append([pos.x, pos.y, pos.z])


        X = np.array(coords, dtype=float)


        X = X - X.mean(axis=0, keepdims=True)


        # PCA via SVD


        U, S, VT = np.linalg.svd(X, full_matrices=False)


        # Project onto principal axes


        Y = X @ VT.T


        # Width along 2nd axis (index 1) as max-min range


        b2 = float(Y[:, 1].max() - Y[:, 1].min())


        return b2


    except Exception:


        return None




def compute_I3_meta_indicator(mol: Chem.Mol) -> int:


    """Return 1 if any benzene (6-membered aromatic ring) is meta-disubstituted; else 0.
    A ring is meta-disubstituted if two ring atoms bearing exocyclic substituents are separated by 2 bonds along the ring.
    """


    ri = mol.GetRingInfo()


    rings = ri.AtomRings()


    for ring in rings:


        if len(ring) != 6:


            continue


        # Check aromaticity for all atoms in ring


        if not all(mol.GetAtomWithIdx(i).GetIsAromatic() for i in ring):


            continue


        ring_list = list(ring)  # RDKit provides ring atoms in order


        ring_set = set(ring_list)


        # Identify substituted ring atoms (have neighbor outside the ring)


        substituted = []


        for idx in ring_list:


            atom = mol.GetAtomWithIdx(idx)


            for nbr in atom.GetNeighbors():


                if nbr.GetIdx() not in ring_set:


                    substituted.append(idx)


                    break


        # Check any pair for meta separation (2 bonds along ring)


        n = len(ring_list)


        for i in range(len(substituted)):

            for j in range(i+1, len(substituted)):

                a = substituted[i]

                b = substituted[j]

                ia = ring_list.index(a)

                ib = ring_list.index(b)

                sep = abs(ia - ib)

                sep = min(sep, n - sep)

                if sep == 2:

                    return 1

    return 0



def compute_descriptors(smiles: str) -> Dict[str, Optional[float]]:

    """Compute α (HBD count), π (logP), MR (molar refractivity), B2 (width), I3 (meta indicator)."""

    mol = Chem.MolFromSmiles(smiles)

    if mol is None:

        return {"alpha": None, "pi": None, "MR": None, "B2": None, "I3": None}

    # For 3D-dependent features, work on a copy with Hs if needed

    try:

        m3d = Chem.AddHs(mol)

    except Exception:

        m3d = mol

    # Basic descriptors

    try:

        alpha = float(rdMolDescriptors.CalcNumHBD(mol))

    except Exception:

        alpha = None

    try:

        pi = float(Crippen.MolLogP(mol))

    except Exception:

        pi = None

    try:

        MR = float(Crippen.MolMR(mol))

    except Exception:

        MR = None

    # B2 and I3

    B2 = compute_b2(m3d)

    try:

        I3 = int(compute_I3_meta_indicator(mol))

    except Exception:

        I3 = None

    return {"alpha": alpha, "pi": pi, "MR": MR, "B2": B2, "I3": I3}

# %%
# CSV processing pipeline without pandas
import csv
from pathlib import Path
from typing import Optional, List, Dict
import pandas as pd

def reduce_memory_usage(df: pd.DataFrame) -> pd.DataFrame:
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    for col in df.columns:
        col_type = df[col].dtype
        if str(col_type) in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if pd.isna(c_min) or pd.isna(c_max):
                continue
            if str(col_type).startswith('int'):
                if c_min >= np.iinfo(np.int8).min and c_max <= np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min >= np.iinfo(np.int16).min and c_max <= np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min >= np.iinfo(np.int32).min and c_max <= np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
            else:
                if c_min >= np.finfo(np.float32).min and c_max <= np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
        elif col_type == object:
            num_unique = df[col].nunique(dropna=False)
            if num_unique / max(len(df), 1) < 0.5:
                df[col] = df[col].astype('category')
    return df

def _guess_column(headers: List[str], candidates: List[str]) -> Optional[str]:
    lc_map = {h.lower(): h for h in headers}
    for cand in candidates:
        for name_lc, orig in lc_map.items():
            if cand in name_lc:
                return orig
    return None


def process_csv(input_path: str, smiles_col: str = None, tm_col: str = None, output_path: str = None) -> List[Dict[str, object]]:
    p = Path(input_path)
    if not p.exists():
        raise FileNotFoundError(f"Input file not found: {input_path}")

    # Read input rows
    with p.open("r", newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        headers = reader.fieldnames or []
        if smiles_col is None:
            smiles_col = _guess_column(headers, ["smiles", "smile", "smile_string", "canonical_smiles"]) or "smiles"
        if tm_col is None:
            tm_col = _guess_column(headers, ["tm", "melt", "melting", "melting_point"]) or "tm"
        if smiles_col not in headers:
            raise ValueError(f"Could not find SMILES column. Got columns: {headers}")
        if tm_col not in headers:
            raise ValueError(f"Could not find Tm column. Got columns: {headers}")

        results: List[Dict[str, object]] = []
        for row in reader:
            smi = row.get(smiles_col, "")
            tm_val = row.get(tm_col, None)
            desc = compute_descriptors(smi)
            rec = {
                "smiles": smi,
                "tm": tm_val,
                **desc,
            }
            results.append(rec)

    # Prepare output path
    if output_path is None:
        out_dir = Path("/home/tp_ubuntu/project/newversion/pubchem-0/result/data")
        out_dir.mkdir(parents=True, exist_ok=True)
        output_path = out_dir / "processed_descriptors.csv"
    else:
        output_path = Path(output_path)
        output_path.parent.mkdir(parents=True, exist_ok=True)

    # Write CSV
    fieldnames = ["smiles", "tm", "alpha", "pi", "MR", "B2", "I3"]
    with output_path.open("w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for rec in results:
            writer.writerow({k: rec.get(k, None) for k in fieldnames})

    print(f"Wrote {len(results)} rows to: {output_path}")
    return reduce_memory_usage(pd.DataFrame(results))

# %%
# Example run on main-data/melting_point_pubchem.csv


default_input = "/home/tp_ubuntu/project/main-data/melting_point_pubchem.csv"

try:

    processed = process_csv(default_input)

    display(processed.head())

except Exception as e:

    print(f"Processing skipped or failed: {e}")
# Out:
# [16:02:57] UFFTYPER: Unrecognized charge state for atom: 1
# [16:02:57] UFFTYPER: Unrecognized charge state for atom: 1
# [16:02:57] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:02:57] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:02:57] UFFTYPER: Unrecognized charge state for atom: 1
# [16:02:57] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:00] WARNING: not removing hydrogen atom without neighbors
# [16:03:00] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:00] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:00] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:00] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:00] UFFTYPER: Unrecognized atom type: Ni3+2 (0)
# [16:03:00] UFFTYPER: Unrecognized atom type: Ni3+2 (0)
# [16:03:00] UFFTYPER: Unrecognized atom type: Ni5+2 (0)
# [16:03:00] UFFTYPER: Unrecognized atom type: Ni5+2 (0)
# [16:03:00] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:00] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:00] UFFTYPER: Unrecognized charge state for atom: 10
# [16:03:00] UFFTYPER: Unrecognized charge state for atom: 10
# [16:03:00] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:00] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:01] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:01] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:02] UFFTYPER: Unrecognized atom type: Pt5+2 (1)
# [16:03:02] UFFTYPER: Unrecognized atom type: Pt5+2 (3)
# [16:03:02] UFFTYPER: Unrecognized atom type: Pt6+2 (1)
# [16:03:02] UFFTYPER: Unrecognized atom type: Pt6+2 (1)
# [16:03:08] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:08] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:09] UFFTYPER: Unrecognized atom type: Kr3+4 (0)
# [16:03:09] UFFTYPER: Unrecognized atom type: Kr3+4 (0)
# [16:03:10] UFFTYPER: Unrecognized atom type: Zn1+2 (1)
# [16:03:10] UFFTYPER: Unrecognized atom type: Zn1+2 (1)
# [16:03:13] UFFTYPER: Warning: hybridization set to SP for atom 9
# [16:03:13] UFFTYPER: Unrecognized charge state for atom: 9
# [16:03:13] UFFTYPER: Warning: hybridization set to SP for atom 9
# [16:03:13] UFFTYPER: Unrecognized charge state for atom: 9
# [16:03:13] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:13] UFFTYPER: Unrecognized atom type: Ca+2 (8)
# [16:03:13] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:03:13] UFFTYPER: Unrecognized atom type: Co3+3 (8)
# [16:03:14] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:14] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:14] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:14] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:14] UFFTYPER: Unrecognized charge state for atom: 2
# [16:03:14] UFFTYPER: Unrecognized atom type: Pb3+3 (2)
# [16:03:14] UFFTYPER: Unrecognized charge state for atom: 2
# [16:03:14] UFFTYPER: Unrecognized atom type: Pb3+3 (2)
# [16:03:16] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:16] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:16] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:16] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:16] UFFTYPER: Unrecognized charge state for atom: 7
# [16:03:16] UFFTYPER: Unrecognized charge state for atom: 7
# [16:03:19] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:19] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:20] UFFTYPER: Unrecognized charge state for atom: 10
# [16:03:20] UFFTYPER: Unrecognized charge state for atom: 10
# [16:03:21] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:03:21] UFFTYPER: Unrecognized atom type: Co3+3 (20)
# [16:03:21] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:21] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:03:21] UFFTYPER: Unrecognized charge state for atom: 12
# [16:03:21] UFFTYPER: Unrecognized atom type: Zn+2 (12)
# [16:03:21] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:21] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:21] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:21] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:21] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:21] UFFTYPER: Unrecognized atom type: Se5+2 (6)
# [16:03:21] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:21] UFFTYPER: Unrecognized atom type: Se5+2 (6)
# [16:03:22] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:22] UFFTYPER: Unrecognized atom type: Ca+2 (26)
# [16:03:22] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:22] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:22] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:22] UFFTYPER: Warning: hybridization set to SP3 for atom 8
# [16:03:22] UFFTYPER: Unrecognized charge state for atom: 8
# [16:03:22] UFFTYPER: Unrecognized atom type: Pb3+3 (8)
# [16:03:23] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:23] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:23] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:23] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:24] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:24] UFFTYPER: Unrecognized atom type: Ca+2 (4)
# [16:03:25] UFFTYPER: Unrecognized atom type: Ag5+1 (0)
# [16:03:25] UFFTYPER: Unrecognized atom type: Ag5+1 (2)
# [16:03:25] UFFTYPER: Unrecognized atom type: Ba (0)
# [16:03:25] UFFTYPER: Unrecognized atom type: Ba (4)
# [16:03:25] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:25] UFFTYPER: Unrecognized atom type: Cd+2 (0)
# [16:03:25] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:25] UFFTYPER: Unrecognized atom type: Cd+2 (4)
# [16:03:25] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:03:25] UFFTYPER: Unrecognized atom type: Co3+3 (4)
# [16:03:25] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
# [16:03:25] UFFTYPER: Unrecognized atom type: Fe2+2 (6)
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:26] UFFTYPER: Unrecognized atom type: Cd+2 (0)
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 8
# [16:03:26] UFFTYPER: Unrecognized atom type: Cd+2 (8)
# [16:03:26] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:26] UFFTYPER: Unrecognized atom type: Ca+2 (6)
# [16:03:26] UFFTYPER: Unrecognized atom type: Cu5+1 (0)
# [16:03:26] UFFTYPER: Unrecognized atom type: Cu5+1 (2)
# [16:03:26] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:26] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:26] UFFTYPER: Warning: hybridization set to SP3 for atom 16
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 16
# [16:03:26] UFFTYPER: Unrecognized atom type: Pb3+3 (16)
# [16:03:26] UFFTYPER: Unrecognized atom type: Ti+4 (0)
# [16:03:26] UFFTYPER: Unrecognized atom type: Ti+4 (16)
# [16:03:26] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:26] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:26] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:26] UFFTYPER: Warning: hybridization set to SP3 for atom 9
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 9
# [16:03:26] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:26] UFFTYPER: Warning: hybridization set to SP3 for atom 40
# [16:03:26] UFFTYPER: Unrecognized charge state for atom: 40
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:27] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 40
# [16:03:27] UFFTYPER: Unrecognized atom type: Zn+2 (40)
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:27] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:27] UFFTYPER: Unrecognized atom type: Zn+2 (4)
# [16:03:27] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:27] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:27] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:27] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:27] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:27] UFFTYPER: Warning: hybridization set to SP for atom 18
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 18
# [16:03:27] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:27] UFFTYPER: Warning: hybridization set to SP for atom 6
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:27] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:27] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:27] UFFTYPER: Warning: hybridization set to SP3 for atom 6
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:27] UFFTYPER: Unrecognized atom type: Pb3+3 (6)
# [16:03:27] UFFTYPER: Unrecognized atom type: Mn2+2 (0)
# [16:03:27] UFFTYPER: Unrecognized atom type: Mn2+2 (4)
# [16:03:27] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:27] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:27] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:27] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:27] UFFTYPER: Unrecognized atom type: Pb3+3 (4)
# [16:03:29] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:29] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:29] UFFTYPER: Warning: hybridization set to SP3 for atom 60
# [16:03:29] UFFTYPER: Unrecognized charge state for atom: 60
# [16:03:31] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:03:31] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:03:31] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:03:31] UFFTYPER: Unrecognized atom type: Co3+3 (26)
# [16:03:31] UFFTYPER: Unrecognized atom type: Co3+3 (27)
# [16:03:31] UFFTYPER: Unrecognized atom type: Co3+3 (28)
# [16:03:32] UFFTYPER: Unrecognized atom type: Cr1+3 (0)
# [16:03:32] UFFTYPER: Unrecognized atom type: Cr1+3 (12)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Be+2 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Be+2 (2)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 8
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 12
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 16
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 20
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 24
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 27
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 27
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 28
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 28
# [16:03:34] UFFTYPER: Unrecognized atom type: Ga+3 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: As1+3 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ga+3 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: As1+3 (1)
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Unrecognized atom type: As2+3 (1)
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:34] UFFTYPER: Unrecognized atom type: As2+3 (4)
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Unrecognized atom type: As2+3 (1)
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:34] UFFTYPER: Unrecognized atom type: As2+3 (4)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ba (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ba (2)
# [16:03:34] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (2)
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (2)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (3)
# [16:03:34] UFFTYPER: Unrecognized atom type: Ca+2 (4)
# [16:03:34] UFFTYPER: Unrecognized atom type: Cd+2 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Cd+2 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Co3+3 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Co3+3 (1)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 3
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 3
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:34] UFFTYPER: Unrecognized atom type: Mo2+6 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Mo2+6 (1)
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 2
# [16:03:34] UFFTYPER: Unrecognized atom type: Sr (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Sr (2)
# [16:03:34] UFFTYPER: Unrecognized atom type: Th1+4 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Th1+4 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: W_2 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: W_2 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: V_2+5 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: V_2+5 (4)
# [16:03:34] UFFTYPER: Unrecognized atom type: V_2+5 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: V_2+5 (4)
# [16:03:34] UFFTYPER: Unrecognized atom type: U_1+4 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: U_1+4 (6)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:34] UFFTYPER: Unrecognized atom type: Sr (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Sr (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Mo2+6 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Mo2+6 (1)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Co3+3 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Co3+3 (1)
# [16:03:34] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
# [16:03:34] UFFTYPER: Unrecognized atom type: Fe2+2 (3)
# [16:03:34] UFFTYPER: Unrecognized atom type: Fe2+2 (4)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 10
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 10
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (10)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 11
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 11
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (11)
# [16:03:34] UFFTYPER: Warning: hybridization set to SP3 for atom 12
# [16:03:34] UFFTYPER: Unrecognized charge state for atom: 12
# [16:03:34] UFFTYPER: Unrecognized atom type: Pb3+3 (12)
# [16:03:35] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:35] UFFTYPER: Unrecognized atom type: As1+3 (0)
# [16:03:35] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:35] UFFTYPER: Unrecognized atom type: As1+3 (0)
# [16:03:35] UFFTYPER: Unrecognized charge state for atom: 3
# [16:03:35] UFFTYPER: Unrecognized atom type: As1+3 (3)
# [16:03:35] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:35] UFFTYPER: Unrecognized atom type: As1+3 (4)
# [16:03:35] UFFTYPER: Unrecognized atom type: Cr2+3 (1)
# [16:03:35] UFFTYPER: Unrecognized atom type: Cr2+3 (1)
# [16:03:35] UFFTYPER: Unrecognized atom type: Mn2+2 (1)
# [16:03:35] UFFTYPER: Unrecognized atom type: Mn2+2 (1)
# [16:03:36] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:36] UFFTYPER: Unrecognized atom type: Ca+2 (40)
# [16:03:36] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:03:36] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:36] UFFTYPER: Warning: hybridization set to SP for atom 8
# [16:03:36] UFFTYPER: Unrecognized charge state for atom: 8
# [16:03:36] UFFTYPER: Unrecognized atom type: Sr (0)
# [16:03:36] UFFTYPER: Unrecognized atom type: Sr (4)
# [16:03:37] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:37] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:38] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:38] UFFTYPER: Unrecognized atom type: Cd+2 (0)
# [16:03:38] UFFTYPER: Unrecognized charge state for atom: 40
# [16:03:38] UFFTYPER: Unrecognized atom type: Cd+2 (40)
# [16:03:38] UFFTYPER: Unrecognized atom type: S_6+6 (1)
# [16:03:38] UFFTYPER: Unrecognized atom type: S_6+6 (1)
# [16:03:38] UFFTYPER: Unrecognized atom type: S_6+6 (1)
# [16:03:38] UFFTYPER: Unrecognized atom type: S_6+6 (1)
# [16:03:39] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:39] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:39] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:39] UFFTYPER: Unrecognized charge state for atom: 2
# [16:03:39] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:39] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:03:39] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:39] UFFTYPER: Unrecognized atom type: Zn+2 (4)
# [16:03:41] UFFTYPER: Unrecognized atom type: Ba (0)
# [16:03:41] UFFTYPER: Unrecognized atom type: Ba (50)
# [16:03:41] UFFTYPER: Unrecognized atom type: Ti+4 (0)
# [16:03:41] UFFTYPER: Unrecognized atom type: Ti+4 (20)
# [16:03:41] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:41] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:41] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:41] UFFTYPER: Warning: hybridization set to SP3 for atom 11
# [16:03:41] UFFTYPER: Unrecognized charge state for atom: 11
# [16:03:41] UFFTYPER: Unrecognized atom type: Pb3+3 (11)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 5
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Ir3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ir3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Mn3+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Mn3+2 (0)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Mo2+6 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Mo2+6 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Os3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Os3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Pd5+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Pd5+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Pt5+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Pt5+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Pu+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Pu+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Rh3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Rh3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ru3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ru3 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Sm2+3 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Sm2+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ag5+1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ag5+1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ta2+5 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ta2+5 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Tc3+5 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Tc3+5 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Th+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Th+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ti1+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ti1+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: W_2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: W_2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Am+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Am+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ar3+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ar3+4 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Cd+2 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Cd+2 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Ce1+3 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Ce1+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr2+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr2+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cu5+1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cu5+1 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Gd3+3 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Gd3+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Au5+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Au5+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Hf1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Hf1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: U_+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: U_+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: V_2+5 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: V_2+5 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Xe3+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Xe3+4 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Y_1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Y_1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Zr1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Zr1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cf+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cf+3 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Se2+2 (1)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Se2+2 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 5
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (5)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 10
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 10
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (10)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 11
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 11
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (11)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 12
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 12
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (12)
# [16:03:42] UFFTYPER: Unrecognized atom type: Se2+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Se2+2 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Cu6+1 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cu6+1 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 5
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Se2+2 (1)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Se2+2 (1)
# [16:03:42] Explicit valence for atom # 1 Cl, 7, is greater than permitted
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Pd6+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Pd6+2 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ni6+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ni6+2 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Ba (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ba (5)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 5
# [16:03:42] UFFTYPER: Unrecognized atom type: Zn+2 (5)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 10
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 10
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 11
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 11
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 12
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 12
# [16:03:42] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 5
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (5)
# [16:03:42] UFFTYPER: Unrecognized atom type: W_3 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: W_3 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 5
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (5)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ag5+1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ag5+1 (4)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (5)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (10)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (11)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (12)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (5)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (5)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (4)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 8
# [16:03:42] UFFTYPER: Unrecognized atom type: Zn+2 (8)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Zn1+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Zn1+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: S_5+4 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: S_5+4 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Se6+2 (1)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Se6+2 (1)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized atom type: Ag6+1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ag6+1 (0)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 23
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 23
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 5
# [16:03:42] UFFTYPER: Unrecognized atom type: Pb3+3 (5)
# [16:03:42] UFFTYPER: Unrecognized atom type: Mn2+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Mn2+2 (5)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ni3+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ni3+2 (5)
# [16:03:42] UFFTYPER: Unrecognized atom type: Mn3+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Mn3+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ba (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Mn3+2 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Mn3+2 (6)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ba (10)
# [16:03:42] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Be+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cu6+1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cu6+1 (0)
# [16:03:42] Explicit valence for atom # 1 Br, 3, is greater than permitted
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (3)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (5)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (3)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cr3+3 (7)
# [16:03:42] Explicit valence for atom # 1 Br, 5, is greater than permitted
# [16:03:42] UFFTYPER: Unrecognized atom type: Co5+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Co5+3 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cu6+1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Cu6+1 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (8)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (9)
# [16:03:42] UFFTYPER: Unrecognized atom type: Ca+2 (10)
# [16:03:42] Explicit valence for atom # 1 Cl, 3, is greater than permitted
# [16:03:42] UFFTYPER: Unrecognized atom type: Sr (0)
# [16:03:42] UFFTYPER: Unrecognized atom type: Sr (8)
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:42] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:43] UFFTYPER: Unrecognized atom type: Ba (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ba (8)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: In2+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: In2+3 (1)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized atom type: Co5+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Co5+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Co3+3 (14)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ni6+2 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ni6+2 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Fe2+2 (15)
# [16:03:43] UFFTYPER: Unrecognized atom type: Fe2+2 (16)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:43] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:43] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:43] UFFTYPER: Warning: hybridization set to SP for atom 3
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 3
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 5
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 6
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 6
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 10
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 10
# [16:03:43] UFFTYPER: Unrecognized atom type: Sr (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Sr (8)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 15
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 15
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 16
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 16
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 10
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 10
# [16:03:43] UFFTYPER: Unrecognized atom type: Rn3 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Rn3 (0)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP for atom 8
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 8
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Unrecognized atom type: Pb3+3 (0)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 8
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 8
# [16:03:43] UFFTYPER: Unrecognized atom type: Pb3+3 (8)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (7)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr1+3 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr1+3 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr1+3 (15)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr1+3 (16)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:43] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:43] UFFTYPER: Unrecognized atom type: Pb3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 1
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 4
# [16:03:43] UFFTYPER: Unrecognized atom type: Cd1+2 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cd1+2 (1)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Unrecognized atom type: Cd+2 (0)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 5
# [16:03:43] UFFTYPER: Unrecognized atom type: Cd+2 (5)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (8)
# [16:03:43] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Co3+3 (5)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (8)
# [16:03:43] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Co3+3 (8)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ba (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ba (5)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Unrecognized atom type: Cd+2 (0)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 8
# [16:03:43] UFFTYPER: Unrecognized atom type: Cd+2 (8)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ba (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ba (2)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 8
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 8
# [16:03:43] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Fe2+2 (12)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (5)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (5)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (2)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr3+3 (7)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 12
# [16:03:43] UFFTYPER: Unrecognized atom type: Zn+2 (12)
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 13
# [16:03:43] UFFTYPER: Unrecognized atom type: Zn+2 (13)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 11
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 11
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 12
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 12
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 13
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 13
# [16:03:43] UFFTYPER: Unrecognized atom type: W_1 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: W_1 (1)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 8
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:03:43] UFFTYPER: Unrecognized charge state for atom: 2
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (1)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (6)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (7)
# [16:03:43] UFFTYPER: Unrecognized atom type: Ca+2 (8)
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:03:43] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr2+3 (0)
# [16:03:43] UFFTYPER: Unrecognized atom type: Cr2+3 (12)
# ...
# [16:18:34] UFFTYPER: Warning: hybridization set to SP for atom 1
# [16:18:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:18:34] UFFTYPER: Warning: hybridization set to SP for atom 2
# [16:18:34] UFFTYPER: Unrecognized charge state for atom: 2
# [16:18:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:18:34] UFFTYPER: Warning: hybridization set to SP3 for atom 3
# [16:18:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:18:34] UFFTYPER: Warning: hybridization set to SP3 for atom 3
# [16:18:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:18:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:18:34] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:18:34] UFFTYPER: Unrecognized charge state for atom: 1
# [16:18:34] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:18:34] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# [16:18:34] WARNING: not removing hydrogen atom without neighbors
# [16:18:34] WARNING: not removing hydrogen atom without neighbors
# [16:18:34] UFFTYPER: Unrecognized atom type: Cu5+1 (1)
# [16:18:34] UFFTYPER: Unrecognized atom type: Cu5+1 (0)
# [16:18:34] UFFTYPER: Unrecognized atom type: Cu5+1 (1)
# [16:18:34] UFFTYPER: Unrecognized atom type: Cu5+1 (2)
# [16:18:35] WARNING: not removing hydrogen atom without neighbors
# [16:18:35] WARNING: not removing hydrogen atom without neighbors
# [16:18:52] WARNING: not removing hydrogen atom without neighbors
# [16:18:52] UFFTYPER: Unrecognized charge state for atom: 0
# [16:18:52] UFFTYPER: Unrecognized charge state for atom: 1
# [16:18:52] WARNING: not removing hydrogen atom without neighbors
# [16:18:52] WARNING: not removing hydrogen atom without neighbors
# [16:18:52] WARNING: not removing hydrogen atom without neighbors
# [16:18:52] WARNING: not removing hydrogen atom without neighbors
# [16:18:52] WARNING: not removing hydrogen atom without neighbors
# [16:18:52] WARNING: not removing hydrogen atom without neighbors
# [16:18:52] WARNING: not removing hydrogen atom without neighbors
# [16:18:53] WARNING: not removing hydrogen atom without neighbors
# [16:18:53] WARNING: not removing hydrogen atom without neighbors
# [16:18:53] WARNING: not removing hydrogen atom without neighbors
# [16:18:53] WARNING: not removing hydrogen atom without neighbors
# [16:18:53] WARNING: not removing hydrogen atom without neighbors
# [16:18:54] WARNING: not removing hydrogen atom without neighbors
# [16:18:54] WARNING: not removing hydrogen atom without neighbors
# [16:18:54] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:18:54] UFFTYPER: Unrecognized charge state for atom: 1
# [16:18:54] UFFTYPER: Warning: hybridization set to SP3 for atom 3
# [16:18:54] UFFTYPER: Unrecognized charge state for atom: 3
# [16:18:54] UFFTYPER: Unrecognized atom type: Ni3+2 (0)
# [16:18:54] UFFTYPER: Unrecognized atom type: Ni3+2 (0)
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:18:55] UFFTYPER: Unrecognized atom type: Co3+3 (10)
# [16:18:55] UFFTYPER: Unrecognized atom type: Cr3+3 (1)
# [16:18:55] UFFTYPER: Unrecognized atom type: Cr3+3 (5)
# [16:18:55] UFFTYPER: Unrecognized atom type: Cr+3 (0)
# [16:18:55] UFFTYPER: Unrecognized atom type: Cr+3 (4)
# [16:18:55] UFFTYPER: Unrecognized atom type: Cr1+3 (0)
# [16:18:55] UFFTYPER: Unrecognized atom type: Cr1+3 (10)
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:55] WARNING: not removing hydrogen atom without neighbors
# [16:18:56] WARNING: not removing hydrogen atom without neighbors
# [16:18:56] WARNING: not removing hydrogen atom without neighbors
# [16:18:56] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:18:56] UFFTYPER: Unrecognized atom type: Co3+3 (24)
# [16:18:56] UFFTYPER: Unrecognized charge state for atom: 1
# [16:18:56] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:18:56] UFFTYPER: Unrecognized charge state for atom: 0
# [16:18:56] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:18:56] UFFTYPER: Unrecognized charge state for atom: 0
# [16:18:56] UFFTYPER: Unrecognized charge state for atom: 1
# [16:18:56] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:18:56] UFFTYPER: Unrecognized charge state for atom: 4
# [16:18:56] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:18:56] UFFTYPER: Unrecognized charge state for atom: 5
# [16:18:56] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:18:56] UFFTYPER: Unrecognized charge state for atom: 0
# [16:18:56] UFFTYPER: Warning: hybridization set to SP3 for atom 93
# [16:18:56] UFFTYPER: Unrecognized charge state for atom: 93
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (1)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (1)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (1)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (1)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (1)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (1)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (9)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (12)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (15)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (18)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (21)
# [16:18:56] UFFTYPER: Unrecognized atom type: As2+3 (24)
# [16:18:56] UFFTYPER: Unrecognized atom type: Zr (0)
# [16:18:56] UFFTYPER: Unrecognized atom type: Zr (27)
# [16:19:06] WARNING: not removing hydrogen atom without neighbors
# [16:19:06] WARNING: not removing hydrogen atom without neighbors
# [16:19:06] WARNING: not removing hydrogen atom without neighbors
# [16:19:06] WARNING: not removing hydrogen atom without neighbors
# [16:19:06] WARNING: not removing hydrogen atom without neighbors
# [16:19:06] WARNING: not removing hydrogen atom without neighbors
# [16:19:06] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
# [16:19:06] UFFTYPER: Unrecognized atom type: Fe2+2 (26)
# [16:19:06] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:19:06] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:19:07] UFFTYPER: Unrecognized atom type: Zr1 (1)
# [16:19:07] UFFTYPER: Unrecognized atom type: Zr1 (7)
# [16:19:07] UFFTYPER: Unrecognized atom type: Pt5+2 (1)
# [16:19:07] UFFTYPER: Unrecognized atom type: Pt5+2 (3)
# [16:19:10] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:19:10] UFFTYPER: Unrecognized atom type: Co3+3 (10)
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:10] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:10] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:10] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 1
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 2
# [16:19:10] UFFTYPER: Unrecognized atom type: Zn+2 (2)
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 3
# [16:19:10] UFFTYPER: Unrecognized atom type: Zn+2 (3)
# [16:19:10] UFFTYPER: Unrecognized charge state for atom: 4
# [16:19:10] UFFTYPER: Unrecognized atom type: Zn+2 (4)
# [16:19:10] UFFTYPER: Unrecognized atom type: Ni5+2 (1)
# [16:19:10] UFFTYPER: Unrecognized atom type: Ni5+2 (1)
# [16:19:10] UFFTYPER: Unrecognized atom type: Ni5+2 (0)
# [16:19:10] UFFTYPER: Unrecognized atom type: Ni5+2 (1)
# [16:19:10] UFFTYPER: Unrecognized atom type: Ni5+2 (3)
# [16:19:10] UFFTYPER: Unrecognized atom type: Ni5+2 (4)
# [16:19:12] UFFTYPER: Warning: hybridization set to SP for atom 0
# [16:19:12] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:12] UFFTYPER: Warning: hybridization set to SP for atom 4
# [16:19:12] UFFTYPER: Unrecognized charge state for atom: 4
# [16:19:14] UFFTYPER: Unrecognized atom type: Co2+3 (0)
# [16:19:14] UFFTYPER: Unrecognized atom type: Co2+3 (91)
# [16:19:19] UFFTYPER: Unrecognized atom type: U_+4 (0)
# [16:19:19] UFFTYPER: Unrecognized atom type: U_+4 (2)
# [16:19:23] UFFTYPER: Unrecognized atom type: Zr6 (1)
# [16:19:23] UFFTYPER: Unrecognized atom type: Zr6 (1)
# [16:19:23] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:19:23] UFFTYPER: Unrecognized atom type: Ca+2 (3)
# [16:19:24] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:19:24] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:24] UFFTYPER: Unrecognized atom type: In2+3 (0)
# [16:19:24] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:19:24] UFFTYPER: Unrecognized charge state for atom: 2
# [16:19:24] UFFTYPER: Unrecognized atom type: In2+3 (2)
# [16:19:28] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:19:28] UFFTYPER: Unrecognized atom type: Fe2+2 (1)
# [16:19:28] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:19:28] UFFTYPER: Unrecognized atom type: Fe2+2 (1)
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:19:29] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:19:29] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 8
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 11
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 14
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 16
# [16:19:29] UFFTYPER: Unrecognized charge state for atom: 16
# [16:19:29] UFFTYPER: Warning: hybridization set to SP3 for atom 17
# [16:19:29] UFFTYPER: Unrecognized charge state for atom: 17
# [16:19:30] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:19:30] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:30] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:19:30] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:30] UFFTYPER: Warning: hybridization set to SP3 for atom 3
# [16:19:30] UFFTYPER: Unrecognized charge state for atom: 3
# [16:19:30] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# [16:19:30] UFFTYPER: Unrecognized charge state for atom: 4
# [16:19:43] UFFTYPER: Unrecognized atom type: Ca+2 (0)
# [16:19:43] UFFTYPER: Unrecognized atom type: Ca+2 (10)
# [16:19:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:19:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:43] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:19:43] UFFTYPER: Unrecognized charge state for atom: 0
# [16:19:43] UFFTYPER: Warning: hybridization set to SP3 for atom 25
# [16:19:43] UFFTYPER: Unrecognized charge state for atom: 25
# [16:19:43] UFFTYPER: Warning: hybridization set to SP3 for atom 26
# [16:19:43] UFFTYPER: Unrecognized charge state for atom: 26
# [16:19:43] UFFTYPER: Unrecognized atom type: Ge (0)
# [16:19:43] UFFTYPER: Unrecognized atom type: Ge (0)
# [16:20:07] UFFTYPER: Unrecognized atom type: V_+5 (0)
# [16:20:07] UFFTYPER: Unrecognized atom type: V_+5 (12)
# [16:20:07] UFFTYPER: Unrecognized atom type: Ti+4 (0)
# [16:20:07] UFFTYPER: Unrecognized atom type: Ti+4 (12)
# [16:20:10] WARNING: not removing hydrogen atom without neighbors
# [16:20:10] UFFTYPER: Unrecognized atom type: Co3+3 (0)
# [16:20:10] UFFTYPER: Unrecognized atom type: Co3+3 (9)
# [16:20:10] UFFTYPER: Unrecognized atom type: Cr1+3 (0)
# [16:20:10] UFFTYPER: Unrecognized atom type: Cr1+3 (0)
# [16:20:10] UFFTYPER: Unrecognized atom type: Cr1+3 (96)
# [16:20:10] UFFTYPER: Unrecognized atom type: Cr1+3 (97)
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:20:41] UFFTYPER: Unrecognized charge state for atom: 0
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:20:41] UFFTYPER: Unrecognized charge state for atom: 0
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [16:20:41] UFFTYPER: Unrecognized charge state for atom: 0
# [16:20:41] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
# [16:20:41] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 9
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 13
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 17
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 21
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 25
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 29
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 34
# [16:20:41] UFFTYPER: Unrecognized charge state for atom: 34
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 35
# [16:20:41] UFFTYPER: Unrecognized charge state for atom: 35
# [16:20:41] UFFTYPER: Warning: hybridization set to SP3 for atom 36
# [16:20:41] UFFTYPER: Unrecognized charge state for atom: 36
# [16:20:41] UFFTYPER: Unrecognized atom type: Fe2+2 (37)
# [16:20:41] UFFTYPER: Unrecognized atom type: Fe2+2 (38)
# [16:20:42] UFFTYPER: Unrecognized atom type: B_1 (0)
# [16:20:42] UFFTYPER: Unrecognized atom type: B_1 (9)
# [16:20:42] UFFTYPER: Unrecognized atom type: B_1 (0)
# [16:20:42] UFFTYPER: Unrecognized atom type: B_1 (9)
# [16:20:42] UFFTYPER: Unrecognized atom type: Pt2+2 (0)
# [16:20:42] UFFTYPER: Unrecognized atom type: Pt2+2 (4)
# [16:20:43] WARNING: not removing hydrogen atom without neighbors
# [16:20:44] UFFTYPER: Unrecognized atom type: U_1+4 (1)
# [16:20:44] UFFTYPER: Unrecognized atom type: U_1+4 (9)
# [16:20:50] UFFTYPER: Unrecognized charge state for atom: 0
# [16:20:50] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [16:20:50] UFFTYPER: Unrecognized charge state for atom: 4
# [16:20:50] UFFTYPER: Unrecognized atom type: Zn+2 (4)
# [16:20:52] WARNING: not removing hydrogen atom without neighbors
# [16:20:52] WARNING: not removing hydrogen atom without neighbors
# [16:20:52] WARNING: not removing hydrogen atom without neighbors
# [16:20:52] WARNING: not removing hydrogen atom without neighbors
# [16:20:52] WARNING: not removing hydrogen atom without neighbors
# [16:20:52] WARNING: not removing hydrogen atom without neighbors
